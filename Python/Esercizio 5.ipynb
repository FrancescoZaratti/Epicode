# %%
import pandas as pd

percorso = 'C:/Users/Franc/Epicode/Mappa-dei-pub-circoli-locali-in-Italia.json'
pub = pd.read_json (percorso, encoding="latin1")
pub
# Out:
#              ccomune             cprovincia  cregione            cnome  \
# 0              ALTRO                  ALTRO     ALTRO
# 1              ALTRO                  ALTRO     ALTRO      Lenny's Pub
# 2              ALTRO                  ALTRO     ALTRO  Murrayfield Pub
# 3              ALTRO                  ALTRO     ALTRO           Snop?e
# 4       Ala di Stura                 TORINO  Piemonte
# ...              ...                    ...       ...              ...
# 2492   Barletta (BT)  BARLETTA ANDRIA TRANI    Puglia      Santa Croce
# 2493  Bisceglie (BT)  BARLETTA ANDRIA TRANI    Puglia      Auld Dublin
# 2494  Bisceglie (BT)  BARLETTA ANDRIA TRANI    Puglia            Ferus
# 2495      Trani (BT)  BARLETTA ANDRIA TRANI    Puglia          Re Artù
# 2496      Trani (BT)  BARLETTA ANDRIA TRANI    Puglia     Well's Fargo
#
#       canno_inserimento cdata_e_ora_inserimento  \
# 0                  2011    2011-06-25T23:17:43Z
# 1                  2011    2011-07-29T17:22:56Z
# ...

# %%
pub.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2497 entries, 0 to 2496
# Data columns (total 9 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ccomune                           2497 non-null   object
#  1   cprovincia                        2497 non-null   object
#  2   cregione                          2497 non-null   object
#  3   cnome                             2497 non-null   object
#  4   canno_inserimento                 2497 non-null   int64
#  5   cdata_e_ora_inserimento           2497 non-null   object
#  6   cidentificatore_in_openstreetmap  2497 non-null   int64
#  7   clongitudine                      2497 non-null   float64
#  8   clatitudine                       2497 non-null   float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 175.7+ KB

# %%
pub.shape
# Out:
# (2497, 9)

# %%
pub.head(1)
# Out:
#   ccomune cprovincia cregione cnome  canno_inserimento  \
# 0   ALTRO      ALTRO    ALTRO                     2011
#
#   cdata_e_ora_inserimento  cidentificatore_in_openstreetmap  clongitudine  \
# 0    2011-06-25T23:17:43Z                        1339088150     13.733257
#
#    clatitudine
# 0     45.57583

# %%
pub.tail (1)
# Out:
#          ccomune             cprovincia cregione         cnome  \
# 2496  Trani (BT)  BARLETTA ANDRIA TRANI   Puglia  Well's Fargo
#
#       canno_inserimento cdata_e_ora_inserimento  \
# 2496               2009    2009-08-10T12:44:03Z
#
#       cidentificatore_in_openstreetmap  clongitudine  clatitudine
# 2496                         387223648     16.436765    41.267264

# %%
pub.sample (1)
# Out:
#         ccomune             cprovincia   cregione      cnome  \
# 2444  Meda (MB)  MONZA E DELLA BRIANZA  Lombardia  Video Pub
#
#       canno_inserimento cdata_e_ora_inserimento  \
# 2444               2015    2015-02-01T09:20:21Z
#
#       cidentificatore_in_openstreetmap  clongitudine  clatitudine
# 2444                        3324784688      9.156631    45.668845

# %%
pub ['anno_inserimento'] = pd.to_datetime (pub ['cdata_e_ora_inserimento'])
pub ['anno_inserimento'] = pub ['anno_inserimento'].dt.year
pub ['anno_inserimento'].value_counts ()
# Out:
# anno_inserimento
# 2015    527
# 2014    464
# 2012    447
# 2013    405
# 2011    244
# 2010    186
# 2009    109
# 2016     66
# 2008     48
# 2007      1
# Name: count, dtype: int64

# %%
mask = pub ['clongitudine'].astype(int).between (9,10)
mask_2 = pub ['clatitudine'].astype(int).between (45,46)

pub. loc [(mask) & (mask_2)].sort_values (['clongitudine', 'clatitudine'])
# Out:
#      ccomune cprovincia   cregione  \
# 342  Origgio     VARESE  Lombardia
# 343  Origgio     VARESE  Lombardia
# 2      ALTRO      ALTRO      ALTRO
# 347  Saronno     VARESE  Lombardia
# 346  Saronno     VARESE  Lombardia
# ..       ...        ...        ...
# 950   Verona     VERONA     Veneto
# 957   Verona     VERONA     Veneto
# 961   Verona     VERONA     Veneto
# 958   Verona     VERONA     Veneto
# 955   Verona     VERONA     Veneto
#
#                                            cnome  canno_inserimento  \
# 342                                                            2010
# 343                                   Buenavista               2012
# 2                                Murrayfield Pub               2015
# 347                                    Bray Hill               2014
# 346                                                            2012
# ..                                           ...                ...
# ...

# %%
mask_1 = pub ['cprovincia'] == 'VICENZA'

pub.loc [mask_1].sort_values ('cnome')
# Out:
#                  ccomune cprovincia cregione                     cnome  \
# 1033   Valli del Pasubio    VICENZA   Veneto
# 988              Cassola    VICENZA   Veneto
# 1015       Recoaro Terme    VICENZA   Veneto
# 1032   Valli del Pasubio    VICENZA   Veneto
# 969   Bassano del Grappa    VICENZA   Veneto                 Al Porton
# ...                  ...        ...      ...                       ...
# 999              Lusiana    VICENZA   Veneto  Vecchia Osteria Bertiaga
# 968               Asiago    VICENZA   Veneto            Vecchio Mulino
# 1021               Rosa'    VICENZA   Veneto          Vinile Disco Pub
# 1024            Sandrigo    VICENZA   Veneto               Wallace Pub
# 1017   Romano d'Ezzelino    VICENZA   Veneto        ex CUBA LIBRE CAFÈ
#
#       canno_inserimento cdata_e_ora_inserimento  \
# 1033               2010    2010-05-05T20:01:30Z
# 988                2011    2011-11-23T12:16:51Z
# 1015               2014    2014-05-19T08:50:13Z
# ...

# %%
#?? Quante enoteche ci sono, e come si chiamano?

# %%
mask = pub ['cregione'].isin (['Lazio', 'Abruzzo'])
pub.loc [mask].sort_values ('cnome')
# Out:
#                      ccomune cprovincia cregione                cnome  \
# 1834                    Roma       ROMA    Lazio
# 2038   Anversa degli Abruzzi   L'AQUILA  Abruzzo
# 2037   Anversa degli Abruzzi   L'AQUILA  Abruzzo
# 1922  San Polo dei Cavalieri       ROMA    Lazio
# 1827                    Roma       ROMA    Lazio
# ...                      ...        ...      ...                  ...
# 1785                 Bolsena    VITERBO    Lazio                 fidA
# 1876                    Roma       ROMA    Lazio              iLocale
# 1874                    Roma       ROMA    Lazio  il bosco degli elfi
# 1935                    Cori     LATINA    Lazio       la cantinaccia
# 1914                    Roma       ROMA    Lazio        the Apartment
#
#       canno_inserimento cdata_e_ora_inserimento  \
# 1834               2015    2015-07-22T03:34:23Z
# 2038               2015    2015-10-08T17:21:36Z
# 2037               2015    2015-10-08T17:17:59Z
# ...

# %%
percorso = 'C:/Users/Franc/Epicode/beginner_datasets_1/iris.csv'
iris = pd.read_csv (percorso)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
means = iris ['petal_length'].mean()
print ('La lunghezza media di tutti i petali è di', round (means,2),'cm')
# Out:
# La lunghezza media di tutti i petali è di 3.76 cm

# %%
iris. groupby ('species')['petal_length'].mean()
# Out:
# species
# Iris-setosa        1.464
# Iris-versicolor    4.260
# Iris-virginica     5.552
# Name: petal_length, dtype: float64

# %%
iris.groupby ('species')['petal_width'].agg(['sum', 'mean', 'max'])
# Out:
#                    sum   mean  max
# species
# Iris-setosa       12.2  0.244  0.6
# Iris-versicolor   66.3  1.326  1.8
# Iris-virginica   101.3  2.026  2.5

# %%
percorso = 'C:/Users/Franc/Epicode/beginner_datasets_1/wine.csv'
wines = pd.read_csv (percorso)
wines
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
print ('Media totale di concentrazione alcolica')

print (wines ['alcohol'].mean())

print ('\nMedia di concentrazione alcolica per ogni qualità')

round ((wines. groupby ('quality') ['alcohol'].mean()), 2)
# Out:
# Media totale di concentrazione alcolica
# 10.491800831149453
#
# Media di concentrazione alcolica per ogni qualità
# quality
# 3    10.22
# 4    10.18
# 5     9.84
# 6    10.59
# 7    11.39
# 8    11.68
# 9    12.18
# Name: alcohol, dtype: float64

# %%
print ('Media totale di concentrazione alcolica')

print (wines ['alcohol'].mean())

print ('\nMedia di concentrazione alcolica per ogni qualità')

round ( (wines. groupby (['type','quality']) ['alcohol'].mean()), 2)
# Out:
# Media totale di concentrazione alcolica
# 10.491800831149453
#
# Media di concentrazione alcolica per ogni qualità
# type   quality
# red    3           9.96
#        4          10.27
#        5           9.90
#        6          10.63
#        7          11.47
#        8          12.09
# white  3          10.34
#        4          10.15
#        5           9.81
#        6          10.58
#        7          11.37
#        8          11.64
#        9          12.18
# Name: alcohol, dtype: float64

# %%
print ('Media totale del pH')

print (round ((wines ['pH'].mean()), 2) )

print ('\nMedia del pH per ogni qualità')

round ( (wines. groupby (['type','quality']) ['pH'].mean()), 2)
# Out:
# Media totale del pH
# 3.22
#
# Media del pH per ogni qualità
# type   quality
# red    3          3.40
#        4          3.38
#        5          3.30
#        6          3.32
#        7          3.29
#        8          3.27
# white  3          3.19
#        4          3.18
#        5          3.17
#        6          3.19
#        7          3.21
#        8          3.22
#        9          3.31
# Name: pH, dtype: float64

# %%
employees_df = pd.DataFrame({
'employee_id': [101, 102, 103, 104, 105],
'name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma'],
'department_id': [1, 2, 1, 2, 3]
})

departments_df = pd.DataFrame({
'department_id': [1, 2, 3],
'department_name': ['HR', 'IT', 'Finance'],
'location': ['New York', 'San Francisco', 'Chicago']
})

# %%
employees_df
# Out:
#    employee_id     name  department_id
# 0          101    Alice              1
# 1          102      Bob              2
# 2          103  Charlie              1
# 3          104    David              2
# 4          105     Emma              3

# %%
departments_df
# Out:
#    department_id department_name       location
# 0              1              HR       New York
# 1              2              IT  San Francisco
# 2              3         Finance        Chicago

# %%
employees_df.merge (departments_df, how = 'left', on = 'department_id')
# Out:
#    employee_id     name  department_id department_name       location
# 0          101    Alice              1              HR       New York
# 1          102      Bob              2              IT  San Francisco
# 2          103  Charlie              1              HR       New York
# 3          104    David              2              IT  San Francisco
# 4          105     Emma              3         Finance        Chicago

# %%
employees_df.set_index ('department_id', inplace = True)

# %%
employees_df
# Out:
#                employee_id     name
# department_id
# 1                      101    Alice
# 2                      102      Bob
# 1                      103  Charlie
# 2                      104    David
# 3                      105     Emma

# %%
departments_df.set_index ('department_id', inplace = True)

# %%
departments_df
# Out:
#               department_name       location
# department_id
# 1                          HR       New York
# 2                          IT  San Francisco
# 3                     Finance        Chicago

# %%
employees_df.join (departments_df)
# Out:
#                employee_id     name department_name       location
# department_id
# 1                      101    Alice              HR       New York
# 1                      103  Charlie              HR       New York
# 2                      102      Bob              IT  San Francisco
# 2                      104    David              IT  San Francisco
# 3                      105     Emma         Finance        Chicago

# %%
# ?? Ci sono differenze nel risultato? Quali? Perché?

# %%
from sqlalchemy import create_engine
import dotenv
import os
import pandas as pd
dotenv.load_dotenv(override=True)
username = os.getenv('username')
password = os.getenv('password')
host = os.getenv('host')
dbname = os.getenv('dbname')

import pandas as pd
dbname = "AdventureWorksDW"
conn_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
db_engine = create_engine(conn_string)
query = """SELECT *
        FROM dimemployee
        """
employee = pd.read_sql(query, db_engine)

# %%
employee
# Out:
#      EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 0              1               18.0                        14417807
# 1              2                7.0                       253022876
# 2              3               14.0                       509647174
# 3              4                3.0                       112457891
# 4              5                3.0                       112457891
# ..           ...                ...                             ...
# 291          292              290.0                       134219713
# 292          293              272.0                        90836195
# 293          294              277.0                       481044938
# 294          295              290.0                       954276278
# 295          296              294.0                       758596752
#
#      ParentEmployeeNationalIDAlternateKey FirstName           LastName  \
# 0                             446466105.0       Guy            Gilbert
# ...

# %%
from sqlalchemy import create_engine
import dotenv
import os
import pandas as pd
dotenv.load_dotenv(override=True)
username = os.getenv('username')
password = os.getenv('password')
host = os.getenv('host')
dbname = os.getenv('dbname')

import pandas as pd
dbname = "AdventureWorksDW"
conn_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
db_engine = create_engine(conn_string)
query = """SELECT *
        FROM dimemployeesalesterritory
        """
territory = pd.read_sql(query, db_engine)

# %%
territory
# Out:
#     EmployeeKey  SalesTerritoryKey
# 0           272                  1
# 1           277                  1
# 2           286                  1
# 3           289                  1
# 4           293                  1
# 5           272                  2
# 6           277                  2
# 7           281                  2
# 8           272                  3
# 9           277                  3
# 10          281                  3
# 11          282                  3
# 12          283                  3
# 13          272                  4
# 14          277                  4
# 15          282                  4
# 16          286                  4
# 17          287                  4
# 18          272                  5
# 19          277                  5
# 20          281                  5
# 21          285                  5
# 22          272                  6
# 23          277                  6
# 24          284                  6
# 25          288                  6
# ...

# %%
territory.head()
# Out:
#    EmployeeKey  SalesTerritoryKey
# 0          272                  1
# 1          277                  1
# 2          286                  1
# 3          289                  1
# 4          293                  1

# %%
employee.tail()
# Out:
#      EmployeeKey  ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# 291          292              290.0                       134219713
# 292          293              272.0                        90836195
# 293          294              277.0                       481044938
# 294          295              290.0                       954276278
# 295          296              294.0                       758596752
#
#      ParentEmployeeNationalIDAlternateKey FirstName           LastName  \
# 291                           982310417.0    Ranjit  Varkey Chudukatil
# 292                           502097814.0      Tete        Mensa-Annan
# 293                           112432117.0      Syed              Abbas
# 294                           982310417.0    Rachel             Valdez
# 295                           481044938.0      Lynn           Tsoflias
#
#     MiddleName  NameStyle                  Title    HireDate  ... Gender  \
# ...

# %%
employee. iloc [272]
# Out:
# EmployeeKey                                                                           273
# ParentEmployeeKey                                                                     7.0
# EmployeeNationalIDAlternateKey                                                  323403273
# ParentEmployeeNationalIDAlternateKey                                           24756624.0
# FirstName                                                                          Wanida
# LastName                                                                         Benshoof
# MiddleName                                                                              M
# NameStyle                                                                               0
# Title                                                                 Marketing Assistant
# HireDate                                                                       2010-08-07
# ...

# %%
employee.columns
# Out:
# Index(['EmployeeKey', 'ParentEmployeeKey', 'EmployeeNationalIDAlternateKey',
#        'ParentEmployeeNationalIDAlternateKey', 'FirstName', 'LastName',
#        'MiddleName', 'NameStyle', 'Title', 'HireDate', 'BirthDate', 'LoginID',
#        'EmailAddress', 'Phone', 'MaritalStatus', 'EmergencyContactName',
#        'EmergencyContactPhone', 'SalariedFlag', 'Gender', 'PayFrequency',
#        'BaseRate', 'VacationHours', 'SickLeaveHours', 'CurrentFlag',
#        'SalesPersonFlag', 'DepartmentName', 'EmployeePhoto', 'Position'],
#       dtype='object')

# %%
territory.columns
# Out:
# Index(['EmployeeKey', 'SalesTerritoryKey'], dtype='object')

# %%
emp = employee .set_index ('EmployeeKey')
terr = territory .set_index ('EmployeeKey')

emp_terr = emp.join (terr)
emp_terr
# Out:
#              ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# EmployeeKey
# 1                         18.0                        14417807
# 2                          7.0                       253022876
# 3                         14.0                       509647174
# 4                          3.0                       112457891
# 5                          3.0                       112457891
# ...                        ...                             ...
# 292                      290.0                       134219713
# 293                      272.0                        90836195
# 294                      277.0                       481044938
# 295                      290.0                       954276278
# 296                      294.0                       758596752
#
#              ParentEmployeeNationalIDAlternateKey FirstName  \
# EmployeeKey
# 1                                     446466105.0       Guy
# ...

# %%
employee .shape
# Out:
# (296, 28)

# %%
territory .shape
# Out:
# (39, 2)

# %%
emp_terr .tail()
# Out:
#              ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# EmployeeKey
# 292                      290.0                       134219713
# 293                      272.0                        90836195
# 294                      277.0                       481044938
# 295                      290.0                       954276278
# 296                      294.0                       758596752
#
#              ParentEmployeeNationalIDAlternateKey FirstName  \
# EmployeeKey
# 292                                   982310417.0    Ranjit
# 293                                   502097814.0      Tete
# 294                                   112432117.0      Syed
# 295                                   982310417.0    Rachel
# 296                                   481044938.0      Lynn
#
#                       LastName MiddleName  NameStyle                  Title  \
# EmployeeKey
# 292          Varkey Chudukatil          R          0   Sales Representative
# ...

# %%
from sqlalchemy import create_engine
import dotenv
import os
import pandas as pd
dotenv.load_dotenv(override=True)
username = os.getenv('username')
password = os.getenv('password')
host = os.getenv('host')
dbname = os.getenv('dbname')

import pandas as pd
dbname = "AdventureWorksDW"
conn_string = f"mysql+pymysql://{username}:{password}@{host}/{dbname}"
db_engine = create_engine(conn_string)
query = """SELECT *
        FROM dimsalesterritory
        """
sales = pd.read_sql(query, db_engine)

# %%
sales
# Out:
#     SalesTerritoryKey  SalesTerritoryAlternateKey SalesTerritoryRegion  \
# 0                   1                           1            Northwest
# 1                   2                           2            Northeast
# 2                   3                           3              Central
# 3                   4                           4            Southwest
# 4                   5                           5            Southeast
# 5                   6                           6               Canada
# 6                   7                           7               France
# 7                   8                           8              Germany
# 8                   9                           9            Australia
# 9                  10                          10       United Kingdom
# 10                 11                           0         Corporate HQ
#
#    SalesTerritoryCountry SalesTerritoryGroup  \
# 0          United States       North America
# ...

# %%
sls = sales .set_index ('SalesTerritoryKey')

# %%
empXterr = emp_terr .set_index ('SalesTerritoryKey')

# %%
s_e_t = empXterr .join (sls)

# %%
s_e_t
# Out:
#                    ParentEmployeeKey  EmployeeNationalIDAlternateKey  \
# SalesTerritoryKey
# 1.0                            277.0                       502097814
# 1.0                            277.0                       112432117
# 1.0                            272.0                        61161660
# 1.0                            272.0                       987554265
# 1.0                            272.0                        90836195
# ...                              ...                             ...
# NaN                              7.0                       222969461
# NaN                              7.0                        52541318
# NaN                             73.0                       895209680
# NaN                             73.0                       895209680
# NaN                             73.0                       895209680
#
#                    ParentEmployeeNationalIDAlternateKey FirstName  \
# SalesTerritoryKey
# ...

# %%
s_e_t ['ParentEmployeeKey'] .unique ()
# Out:
# array([277., 272., 290., 294.,  18.,   7.,  14.,   3., 267., 112.,  23.,
#        189., 177., 201., 188., 111.,  89., 154.,  16., 143., 214., 138.,
#         87.,  40.,   9., 186., 163., 204.,  76.,  32., 222., 126.,  20.,
#         92., 147., 142.,  44.,  43., 162.,  53.,  46.,  nan, 278., 152.,
#         27.,  66.,  51.,  73.])

# %%
# ?? Non capisco quale colonna prendere per contare i dipendenti

# %%
s_e_t .groupby (['SalesTerritoryCountry', 'SalesTerritoryRegion']) ['ParentEmployeeKey'] .count()
# Out:
# SalesTerritoryCountry  SalesTerritoryRegion
# Australia              Australia               3
# Canada                 Canada                  4
# France                 France                  4
# Germany                Germany                 3
# United Kingdom         United Kingdom          3
# United States          Central                 5
#                        Northeast               3
#                        Northwest               5
#                        Southeast               4
#                        Southwest               5
# Name: ParentEmployeeKey, dtype: int64

# %%
s_e_t .groupby (['SalesTerritoryCountry', 'SalesTerritoryRegion']) ['BaseRate'] .mean()
# Out:
# SalesTerritoryCountry  SalesTerritoryRegion
# Australia              Australia               47.764433
# Canada                 Canada                  41.592550
# France                 France                  41.592550
# Germany                Germany                 47.764433
# United Kingdom         United Kingdom          47.764433
# United States          Central                 37.889420
#                        Northeast               47.764433
#                        Northwest               37.889420
#                        Southeast               41.592550
#                        Southwest               37.889420
# Name: BaseRate, dtype: float64
